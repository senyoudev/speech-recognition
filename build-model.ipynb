# %%
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
tf.keras
# Out:
# <module 'keras.api._v2.keras' from 'C:\\Users\\youne\\.conda\\envs\\dl\\lib\\site-packages\\keras\\api\\_v2\\keras\\__init__.py'>

# %%
DATA_PATH = "data.json"
SAVED_MODEL_PATH = "model.h5"
EPOCHS = 40
BATCH_SIZE = 32
PATIENCE = 5
LEARNING_RATE = 0.0001

# %%
def load_data(data_path):
    """Loads training dataset from json file.
    :param data_path (str): Path to json file containing data
    :return X (ndarray): Inputs
    :return y (ndarray): Targets
    """
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["MFCCs"])
    y = np.array(data["labels"])
    print("Training sets loaded!")
    return X, y

# %%
def prepare_dataset(data_path, test_size=0.2, validation_size=0.2):
    """Creates train, validation and test sets.
    :param data_path (str): Path to json file containing data
    :param test_size (flaot): Percentage of dataset used for testing
    :param validation_size (float): Percentage of train set used for cross-validation
    :return X_train (ndarray): Inputs for the train set
    :return y_train (ndarray): Targets for the train set
    :return X_validation (ndarray): Inputs for the validation set
    :return y_validation (ndarray): Targets for the validation set
    :return X_test (ndarray): Inputs for the test set
    :return X_test (ndarray): Targets for the test set
    """

    # load dataset
    X, y = load_data(data_path)

    # create train, validation, test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to nd array
    X_train = X_train[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]

    return X_train, y_train, X_validation, y_validation, X_test, y_test

# %%
def build_model(input_shape, loss="sparse_categorical_crossentropy", learning_rate=0.0001):
    """Build neural network using keras.
    :param input_shape (tuple): Shape of array representing a sample train. E.g.: (44, 13, 1)
    :param loss (str): Loss function to use
    :param learning_rate (float):
    :return model: TensorFlow model
    """

    # build network architecture using convolutional layers
    model = tf.keras.models.Sequential()

    # 1st conv layer
    model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape,
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 2nd conv layer
    model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

    # 3rd conv layer
    model.add(tf.keras.layers.Conv2D(32, (2, 2), activation='relu',
                                     kernel_regularizer=tf.keras.regularizers.l2(0.001)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding='same'))

    # flatten output and feed into dense layer
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(64, activation='relu'))
    tf.keras.layers.Dropout(0.3)

    # softmax output layer
    model.add(tf.keras.layers.Dense(10, activation='softmax'))

    optimiser = tf.optimizers.Adam(learning_rate=learning_rate)

    # compile model
    model.compile(optimizer=optimiser,
                  loss=loss,
                  metrics=["accuracy"])

    # print model parameters on console
    model.summary()

    return model

# %%
def train(model, epochs, batch_size, patience, X_train, y_train, X_validation, y_validation):
    """Trains model
    :param epochs (int): Num training epochs
    :param batch_size (int): Samples per batch
    :param patience (int): Num epochs to wait before early stop, if there isn't an improvement on accuracy
    :param X_train (ndarray): Inputs for the train set
    :param y_train (ndarray): Targets for the train set
    :param X_validation (ndarray): Inputs for the validation set
    :param y_validation (ndarray): Targets for the validation set
    :return history: Training history
    """

    earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=patience)

    # train model
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(X_validation, y_validation),
                        callbacks=[earlystop_callback])
    return history

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
    :param history: Training history of model
    :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy subplot
    axs[0].plot(history.history["accuracy"], label="accuracy")
    axs[0].plot(history.history['val_accuracy'], label="val_accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy evaluation")

    # create loss subplot
    axs[1].plot(history.history["loss"], label="loss")
    axs[1].plot(history.history['val_loss'], label="val_loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Loss")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Loss evaluation")

    plt.show()

# %%
def main():
    # generate train, validation and test sets
    X_train, y_train, X_validation, y_validation, X_test, y_test = prepare_dataset(DATA_PATH)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    model = build_model(input_shape, learning_rate=LEARNING_RATE)

    # train network
    history = train(model, EPOCHS, BATCH_SIZE, PATIENCE, X_train, y_train, X_validation, y_validation)

    # plot accuracy/loss for training/validation set as a function of the epochs
    plot_history(history)

    # evaluate network on test set
    test_loss, test_acc = model.evaluate(X_test, y_test)
    print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))

    # save model
    model.save(SAVED_MODEL_PATH)

# %%
main()
# Out:
# Training sets loaded!
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 42, 11, 64)        640
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 42, 11, 64)        256
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 21, 6, 64)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 19, 4, 32)         18464
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 19, 4, 32)         128
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 2, 32)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 9, 1, 32)          4128
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 9, 1, 32)          128
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 1, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                10304
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# =================================================================
# Total params: 34,698
# Trainable params: 34,442
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 427/427 [==============================] - 10s 22ms/step - loss: 2.1560 - accuracy: 0.2779 - val_loss: 1.7501 - val_accuracy: 0.4185
# Epoch 2/40
# 427/427 [==============================] - 9s 20ms/step - loss: 1.4826 - accuracy: 0.5230 - val_loss: 1.2685 - val_accuracy: 0.6012
# Epoch 3/40
# 427/427 [==============================] - 8s 19ms/step - loss: 1.1284 - accuracy: 0.6552 - val_loss: 1.0122 - val_accuracy: 0.6874
# Epoch 4/40
# 427/427 [==============================] - 9s 21ms/step - loss: 0.9130 - accuracy: 0.7274 - val_loss: 0.8272 - val_accuracy: 0.7534
# Epoch 5/40
# 427/427 [==============================] - 9s 21ms/step - loss: 0.7675 - accuracy: 0.7778 - val_loss: 0.7267 - val_accuracy: 0.7845
# Epoch 6/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.6698 - accuracy: 0.8098 - val_loss: 0.6485 - val_accuracy: 0.8100
# Epoch 7/40
# 427/427 [==============================] - 9s 21ms/step - loss: 0.5985 - accuracy: 0.8350 - val_loss: 0.5825 - val_accuracy: 0.8349
# Epoch 8/40
# 427/427 [==============================] - 10s 23ms/step - loss: 0.5508 - accuracy: 0.8495 - val_loss: 0.5299 - val_accuracy: 0.8481
# Epoch 9/40
# 427/427 [==============================] - 10s 23ms/step - loss: 0.5032 - accuracy: 0.8657 - val_loss: 0.5086 - val_accuracy: 0.8610
# Epoch 10/40
# 427/427 [==============================] - 8s 20ms/step - loss: 0.4683 - accuracy: 0.8781 - val_loss: 0.4900 - val_accuracy: 0.8648
# Epoch 11/40
# 427/427 [==============================] - 10s 23ms/step - loss: 0.4350 - accuracy: 0.8828 - val_loss: 0.4520 - val_accuracy: 0.8830
# Epoch 12/40
# 427/427 [==============================] - 10s 22ms/step - loss: 0.4108 - accuracy: 0.8935 - val_loss: 0.4317 - val_accuracy: 0.8900
# Epoch 13/40
# 427/427 [==============================] - 8s 20ms/step - loss: 0.3899 - accuracy: 0.9018 - val_loss: 0.4588 - val_accuracy: 0.8751
# Epoch 14/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.3744 - accuracy: 0.9042 - val_loss: 0.4168 - val_accuracy: 0.8839
# Epoch 15/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.3523 - accuracy: 0.9111 - val_loss: 0.3911 - val_accuracy: 0.8991
# Epoch 16/40
# 427/427 [==============================] - 8s 20ms/step - loss: 0.3411 - accuracy: 0.9146 - val_loss: 0.3751 - val_accuracy: 0.8991
# Epoch 17/40
# 427/427 [==============================] - 8s 20ms/step - loss: 0.3311 - accuracy: 0.9169 - val_loss: 0.3659 - val_accuracy: 0.9073
# Epoch 18/40
# 427/427 [==============================] - 9s 22ms/step - loss: 0.3128 - accuracy: 0.9240 - val_loss: 0.3572 - val_accuracy: 0.9085
# Epoch 19/40
# 427/427 [==============================] - 8s 20ms/step - loss: 0.3024 - accuracy: 0.9277 - val_loss: 0.3500 - val_accuracy: 0.9114
# Epoch 20/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2909 - accuracy: 0.9298 - val_loss: 0.3582 - val_accuracy: 0.9056
# Epoch 21/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2783 - accuracy: 0.9332 - val_loss: 0.3505 - val_accuracy: 0.9067
# Epoch 22/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.2725 - accuracy: 0.9363 - val_loss: 0.3495 - val_accuracy: 0.9097
# Epoch 23/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.2685 - accuracy: 0.9347 - val_loss: 0.3336 - val_accuracy: 0.9155
# Epoch 24/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2531 - accuracy: 0.9402 - val_loss: 0.3397 - val_accuracy: 0.9100
# Epoch 25/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.2500 - accuracy: 0.9435 - val_loss: 0.3159 - val_accuracy: 0.9170
# Epoch 26/40
# 427/427 [==============================] - 10s 23ms/step - loss: 0.2407 - accuracy: 0.9467 - val_loss: 0.3347 - val_accuracy: 0.9111
# Epoch 27/40
# 427/427 [==============================] - 9s 21ms/step - loss: 0.2333 - accuracy: 0.9477 - val_loss: 0.3686 - val_accuracy: 0.9038
# Epoch 28/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2272 - accuracy: 0.9498 - val_loss: 0.3225 - val_accuracy: 0.9167
# Epoch 29/40
# 427/427 [==============================] - 9s 20ms/step - loss: 0.2198 - accuracy: 0.9519 - val_loss: 0.3278 - val_accuracy: 0.9132
# Epoch 30/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2159 - accuracy: 0.9519 - val_loss: 0.3364 - val_accuracy: 0.9161
# Epoch 31/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2112 - accuracy: 0.9533 - val_loss: 0.3181 - val_accuracy: 0.9208
# Epoch 32/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.2058 - accuracy: 0.9547 - val_loss: 0.3164 - val_accuracy: 0.9176
# Epoch 33/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.1988 - accuracy: 0.9587 - val_loss: 0.3507 - val_accuracy: 0.9076
# Epoch 34/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.1948 - accuracy: 0.9589 - val_loss: 0.3434 - val_accuracy: 0.9082
# Epoch 35/40
# 427/427 [==============================] - 7s 17ms/step - loss: 0.1883 - accuracy: 0.9613 - val_loss: 0.3008 - val_accuracy: 0.9267
# Epoch 36/40
# 427/427 [==============================] - 7s 18ms/step - loss: 0.1811 - accuracy: 0.9641 - val_loss: 0.3176 - val_accuracy: 0.9220
# Epoch 37/40
# 427/427 [==============================] - 8s 18ms/step - loss: 0.1843 - accuracy: 0.9606 - val_loss: 0.3120 - val_accuracy: 0.9223
# Epoch 38/40
# 427/427 [==============================] - 7s 17ms/step - loss: 0.1738 - accuracy: 0.9661 - val_loss: 0.3170 - val_accuracy: 0.9208
# Epoch 39/40
# 427/427 [==============================] - 7s 17ms/step - loss: 0.1729 - accuracy: 0.9660 - val_loss: 0.2964 - val_accuracy: 0.9267
# Epoch 40/40
# 427/427 [==============================] - 8s 19ms/step - loss: 0.1723 - accuracy: 0.9651 - val_loss: 0.3200 - val_accuracy: 0.9167
# 134/134 [==============================] - 1s 9ms/step - loss: 0.3317 - accuracy: 0.9146
#
# Test loss: 0.3317473530769348, test accuracy: 91.46141409873962
